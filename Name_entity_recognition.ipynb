# %% [markdown]
# <a href="https://colab.research.google.com/github/anushikajain/NLP_COURSE/blob/main/Name_entity_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Name Entity Recognition**

# %% [markdown]
# sentences="the Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel ,whose company specialized in building metal framework and structure."
#
#
#
# """
# Person Eg:Krish C Naik
#
# Place OR LOCATION:India
#
# Date eg:september,24-09-35
#
# Time eg:4:30pm
#
# Money eg: 1 Million dollar
#
# Organization eg: ineuron private limited
#
# \Percent eg: 20%,twenty percent
# """

# %%
sentence="the Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel ,whose company specialized in building metal framework and structure."

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
words=nltk.word_tokenize(sentence)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
tag_elements=nltk.pos_tag(words)

# %%
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
from nltk.chunk import tree2conlltags

tree = nltk.ne_chunk(tag_elements)
tree2conlltags(tree)
# Out:
# [('the', 'DT', 'O'),
#  ('Eiffel', 'NNP', 'B-ORGANIZATION'),
#  ('Tower', 'NNP', 'I-ORGANIZATION'),
#  ('was', 'VBD', 'O'),
#  ('built', 'VBN', 'O'),
#  ('from', 'IN', 'O'),
#  ('1887', 'CD', 'O'),
#  ('to', 'TO', 'O'),
#  ('1889', 'CD', 'O'),
#  ('by', 'IN', 'O'),
#  ('French', 'JJ', 'B-GPE'),
#  ('engineer', 'NN', 'O'),
#  ('Gustave', 'NNP', 'B-PERSON'),
#  ('Eiffel', 'NNP', 'I-PERSON'),
#  (',', ',', 'O'),
#  ('whose', 'WP$', 'O'),
#  ('company', 'NN', 'O'),
#  ('specialized', 'VBD', 'O'),
#  ('in', 'IN', 'O'),
#  ('building', 'NN', 'O'),
#  ('metal', 'NN', 'O'),
#  ('framework', 'NN', 'O'),
#  ('and', 'CC', 'O'),
#  ('structure', 'NN', 'O'),
#  ('.', '.', 'O')]
