# %% [markdown]
# <a href="https://colab.research.google.com/github/anushikajain/NLP_COURSE/blob/main/Stemming_And_Its_Types_Text_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Classification Problem
## Comments of product is a positive review or negative review
## Review----> eating,eat,eaten [going,gone,goes]---> go

words=["eating","eat","sing","singing","dance","dancing"]

# %% [markdown]
# ##PorterStemmer

# %%
from nltk.stem import PorterStemmer

# %%
stemming=PorterStemmer()

# %%
for word in words:
    print(word+"----->"+stemming.stem(word))
# Out:
# eating----->eat
# eat----->eat
# sing----->sing
# singing----->sing
# dance----->danc
# dancing----->danc

# %%
stemming.stem("congratulation")
# Out:
# 'congratul'

# %%
stemming.stem("sitting")
# Out:
# 'sit'

# %% [markdown]
# ##RegexpStemmer Class

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer=RegexpStemmer("ing$|s$|e$|able$",min=4)

# %%
reg_stemmer.stem("eating")
# Out:
# 'eat'

# %%
reg_stemmer=RegexpStemmer("ing|s$|e$|able$",min=4)

# %%
reg_stemmer.stem("ingeating")
# Out:
# 'eat'

# %% [markdown]
# ##Snowball stemmer

# %%
from nltk import SnowballStemmer

# %%
snowballsstemmer=SnowballStemmer('english')

# %%
for word in words:
    print(word+"----->"+snowballsstemmer.stem(word))
# Out:
# eating----->eat
# eat----->eat
# sing----->sing
# singing----->sing
# dance----->danc
# dancing----->danc

# %%
stemming.stem("fairly"),stemming.stem("sportingly")
# Out:
# ('fairli', 'sportingli')

# %%
snowballsstemmer.stem("fairly"),snowballsstemmer.stem("sportingly")
# Out:
# ('fair', 'sport')
